# %%
print("hello")
# Out:
# hello

# %%
print("hello is a string")
# Out:
# hello is a string

# %%
10+20
# Out:
# 30

# %%
num1 = 10
num2 = 20
add = num1 + num2
print(num1, num2, add)
# Out:
# 10 20 30

# %%
print ("10&20 is a intiger")
# Out:
# 10&20 is a intiger

# %%
temp = num1
num1 = num2
num2 = temp
print(num1, num2)
# Out:
# 20 10

# %%
num3=30
num4=40
add = num3 + num4
print(add ,num4,num3)
# Out:
# 70 40 30

# %%
temp=num3
num3=num4
num4=temp
print(num4,num3)
print(num3,num4)
# Out:
# 40 30
# 30 40

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
colors = ['gold', 'yellowgreen', 'pink', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.figure(figsize=(8, 8))  # Optional: set the figure size
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
         shadow=True, startangle=150)

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')  

plt.title('pie Chart Example')  # Optional: add a title
plt.show()

#autopct='%1.2f%%'
